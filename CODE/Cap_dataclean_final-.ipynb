# %%
import os
import csv
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

# %% [markdown]
# # read file

# %%
df_abt = pd.read_excel("/Users/Nicole/Desktop/FTDS/Capstone/processed/ABT_L4.xlsx",index_col='date',parse_dates=True)
df_abt.head(20)
# Out:
#                 SMA  FAMA_x  MAMA_x  FAMA_y  MAMA_y    SlowD    SlowK  \
# date
# 2000-01-31  35.6253     NaN     NaN     NaN     NaN      NaN      NaN
# 2000-02-29  33.9587     NaN     NaN     NaN     NaN      NaN      NaN
# 2000-03-31  33.5837     NaN     NaN     NaN     NaN      NaN      NaN
# 2000-04-28  35.5420     NaN     NaN     NaN     NaN      NaN      NaN
# 2000-05-31  38.1047     NaN     NaN     NaN     NaN      NaN      NaN
# 2000-06-30  41.2297     NaN     NaN     NaN     NaN      NaN      NaN
# 2000-07-31  42.2503     NaN     NaN     NaN     NaN  79.1447  84.3408
# 2000-08-31  43.2777     NaN     NaN     NaN     NaN  85.4148  87.0728
# 2000-09-29  44.2777     NaN     NaN     NaN     NaN  84.9502  83.4369
# 2000-10-31  48.0487     NaN     NaN     NaN     NaN  86.3502  88.5408
# 2000-11-30  51.8130     NaN     NaN     NaN     NaN  87.6664  91.0214
# 2000-12-29  52.1047     NaN     NaN     NaN     NaN  86.3731  79.5570
# ...

# %%
df_agn = pd.read_excel("/Users/Geoffrey/Desktop/FTDS/Capstone/processed/AGN_L4.xlsx",index_col='date',parse_dates=True)
df_alxn = pd.read_excel("/Users/Geoffrey/Desktop/FTDS/Capstone/processed/ALXN_L4.xlsx",index_col='date',parse_dates=True)
df_amgn = pd.read_excel("/Users/Geoffrey/Desktop/FTDS/Capstone/processed/AMGN_L4.xlsx",index_col='date',parse_dates=True)
df_bax = pd.read_excel("/Users/Geoffrey/Desktop/FTDS/Capstone/processed/BAX_L4.xlsx",index_col='date',parse_dates=True)
df_biib = pd.read_excel("/Users/Geoffrey/Desktop/FTDS/Capstone/processed/BIIB_L4.xlsx",index_col='date',parse_dates=True)

df_bmrn = pd.read_excel("/Users/Geoffrey/Desktop/FTDS/Capstone/processed/BMRN_L4.xlsx",index_col='date',parse_dates=True)
#df_bmy = pd.read_excel("/Users/Geoffrey/Desktop/FTDS/Capstone/processed/BMY_L4.xlsx",index_col='date',parse_dates=True)
df_celg = pd.read_excel("/Users/Geoffrey/Desktop/FTDS/Capstone/processed/CELG_L4.xlsx",index_col='date',parse_dates=True)
df_dhr = pd.read_excel("/Users/Geoffrey/Desktop/FTDS/Capstone/processed/DHR_L4.xlsx",index_col='date',parse_dates=True)
df_gild = pd.read_excel("/Users/Geoffrey/Desktop/FTDS/Capstone/processed/GILD_L4.xlsx",index_col='date',parse_dates=True)

df_ilmn = pd.read_excel("/Users/Geoffrey/Desktop/FTDS/Capstone/processed/ILMN_L4.xlsx",index_col='date',parse_dates=True)
df_incy = pd.read_excel("/Users/Geoffrey/Desktop/FTDS/Capstone/processed/INCY_L4.xlsx",index_col='date',parse_dates=True)
df_jnj = pd.read_excel("/Users/Geoffrey/Desktop/FTDS/Capstone/processed/JNJ_L4.xlsx",index_col='date',parse_dates=True)
df_lh = pd.read_excel("/Users/Geoffrey/Desktop/FTDS/Capstone/processed/LH_L4.xlsx",index_col='date',parse_dates=True)
df_lly = pd.read_excel("/Users/Geoffrey/Desktop/FTDS/Capstone/processed/LLY_L4.xlsx",index_col='date',parse_dates=True)

df_mrk = pd.read_excel("/Users/Geoffrey/Desktop/FTDS/Capstone/processed/MRK_L4.xlsx",index_col='date',parse_dates=True)
df_pfe = pd.read_excel("/Users/Geoffrey/Desktop/FTDS/Capstone/processed/PFE_L4.xlsx",index_col='date',parse_dates=True)
df_regn = pd.read_excel("/Users/Geoffrey/Desktop/FTDS/Capstone/processed/REGN_L4.xlsx",index_col='date',parse_dates=True)
df_syk = pd.read_excel("/Users/Geoffrey/Desktop/FTDS/Capstone/processed/SYK_L4.xlsx",index_col='date',parse_dates=True)

# %% [markdown]
# # LOOP

# %%
#alldf = [df_abt, df_agn, df_alxn, df_amgn, df_bax, df_biib, df_bmrn, 
         df_bmy, df_celg, df_dhr, df_gild, df_ilmn, df_incy, df_jnj,
        df_lh, df_lly, df_mrk, df_pfe, df_regn, df_syk]

# %%
alldf = [df_abt, df_agn, df_alxn, df_amgn, df_bax, df_biib, df_bmrn,
         df_celg, df_dhr, df_gild, df_ilmn, df_incy, df_jnj,
        df_lh, df_lly, df_mrk, df_pfe, df_regn, df_syk]

# %%
len(alldf)
# Out:
# 19

# %% [markdown]
# ## changing name for Depreciation

# %%
countd=[]
for i in range(len(alldf)):
    for title in alldf[i].columns:
        if title.startswith('Depreciation'):
            countd.append(1)
len(countd)
# Out:
# 11

# %%
counte=[]
for i in range(len(alldf)):
    for title in alldf[i].columns:
        if title.startswith('depreciation'):
            counte.append(1)
len(counte)
# Out:
# 9

# %%
for i in range(len(alldf)):
    for title in alldf[i].columns:
        if title.startswith('depreciation'):
            alldf[i].rename(columns={title:"Depreciation, Depletion and Amortization"}, inplace=True)

# %%
countd1=[]
for i in range(len(alldf)):
    if 'Depreciation, Depletion and Amortization' in alldf[i].columns:
        countd1.append(1)
len(countd1)
# Out:
# 19

# %%
countf=[]
for i in range(len(alldf)):
    for title in alldf[i].columns:
        if title.startswith('Depreciation'):
            countf.append(1)
len(countf)
# Out:
# 20

# %%
countg=[]
for i in range(len(alldf)):
    for title in alldf[i].columns:
        if title.startswith('depreciation'):
            countg.append(1)
len(countg)
# Out:
# 0

# %% [markdown]
# ## upper

# %%
for i in range(len(alldf)):
    for name in alldf[i].columns:
        alldf[i].rename(columns={name:name.upper()}, inplace=True)

# %% [markdown]
# ## remove duplicate columns

# %%
shape =[]
for i in range(len(alldf)):
    shape.append(alldf[i].shape)

shape2=[]
for i in range(len(alldf)):
    alldf[i] = alldf[i].iloc[:, ~alldf[i].columns.duplicated(keep='first')]
    shape2.append(alldf[i].shape)

print(shape)
print(shape2)
# Out:
# [(238, 286), (238, 295), (237, 296), (238, 273), (238, 297), (238, 297), (238, 296), (232, 296), (238, 299), (240, 295), (231, 296), (238, 297), (238, 298), (238, 299), (238, 297), (238, 297), (238, 298), (238, 299), (238, 298)]
# [(238, 286), (238, 295), (237, 296), (238, 273), (238, 297), (238, 297), (238, 296), (232, 295), (238, 298), (240, 294), (231, 295), (238, 296), (238, 297), (238, 299), (238, 297), (238, 297), (238, 297), (238, 298), (238, 296)]

# %% [markdown]
# ### stock

# %%
counts=0
for i in range(len(alldf)):
    if 'STOCK-BASED COMPENSATION' in alldf[i].columns:
        counts+=1
print(counts) 

for i in range(len(alldf)):
    if 'STOCK-BASED COMPENSATION' in alldf[i].columns:
        alldf[i] = alldf[i].drop(['STOCK-BASED COMPENSATION'], axis=1)
    
countS=0
for i in range(len(alldf)):
    if 'STOCK-BASED COMPENSATION' in alldf[i].columns:
        countS+=1
print(countS)
# Out:
# 8
# 0

# %%
alldf[1]
# Out:
#                  CCI  REAL MIDDLE BAND  REAL UPPER BAND  REAL LOWER BAND  \
# date
# 2000-01-31  100.0000           37.7713          41.5370          34.0056
# 2000-02-29   94.3789           38.7087          42.8117          34.6056
# 2000-03-31  -94.1996           40.0003          40.5106          39.4900
# 2000-04-28   89.5955           41.5420          46.3514          36.7326
# 2000-05-31   75.0907           42.9797          47.6627          38.2967
# ...              ...               ...              ...              ...
# 2019-06-28   71.8093          145.4467         182.6785         108.2149
# 2019-07-31   87.3120          149.9467         189.9982         109.8951
# 2019-08-30   23.0838          162.5500         169.4807         155.6193
# 2019-09-30   80.6717          162.8367         170.5751         155.0982
# 2019-10-09   65.9747          164.9167         172.3740         157.4593
#
#                   OBV    SLOWD    SLOWK     MACD  MACD_HIST  MACD_SIGNAL  ...  \
# ...

# %% [markdown]
# ### all at once

# %%
shape3 =[]
shape4 =[]

for i in range(len(alldf)):
    shape3.append(alldf[i].shape)
    
    if 'STOCK-BASED COMPENSATION' in alldf[i].columns:
        alldf[i] = alldf[i].drop(['STOCK-BASED COMPENSATION'], axis=1)
    if 'MARKET CAP' in alldf[i].columns:
        alldf[i] = alldf[i].drop(['MARKET CAP'], axis=1)
    if 'ACCOUNTS PAYABLE.1' in alldf[i].columns:
        alldf[i] = alldf[i].drop(['ACCOUNTS PAYABLE.1'], axis=1)
    if 'NET INCOME FROM CONTINUING OPERATIONS' in alldf[i].columns:
        alldf[i] = alldf[i].drop(['NET INCOME FROM CONTINUING OPERATIONS'], axis=1)
    if 'NET INCOME.1' in alldf[i].columns:
        alldf[i] = alldf[i].drop(['NET INCOME.1'], axis=1)
    if 'NET INCOME ' in alldf[i].columns:
        alldf[i] = alldf[i].drop(['NET INCOME '], axis=1)

for i in range(len(alldf)):
    shape4.append(alldf[i].shape)

print(shape3)
print(shape4)
# Out:
# [(238, 286), (238, 294), (237, 295), (238, 273), (238, 296), (238, 296), (238, 295), (232, 295), (238, 298), (240, 294), (231, 295), (238, 296), (238, 297), (238, 298), (238, 296), (238, 296), (238, 297), (238, 298), (238, 296)]
# [(238, 283), (238, 289), (237, 290), (238, 271), (238, 293), (238, 293), (238, 292), (232, 290), (238, 295), (240, 289), (231, 292), (238, 293), (238, 294), (238, 295), (238, 293), (238, 293), (238, 294), (238, 295), (238, 293)]

# %% [markdown]
# # further find out 漏網之魚

# %%
columns = []
for i in shape4:
    columns.append(i[1])
len(columns)
# Out:
# 19

# %%
max(columns)
# Out:
# 295

# %%
columns.index(294)
# Out:
# 12

# %%
min(columns)
# Out:
# 271

# %%
columns.index(271)
# Out:
# 3

# %%
m_col = []
for i in alldf[3].columns:
    if i not in alldf[13].columns:
        m_col.append(i)
print(m_col)
print(len(m_col))
# Out:
# ['MACD_SIGNAL_X', 'MACD_X', 'MACD_HIST_X', 'MACD_SIGNAL_Y', 'MACD_Y', 'MACD_HIST_Y', 'SLOWK', 'SLOWD', 'RETURN-ON-TANGIBLE-EQUITY', 'RETURN-ON-TANGIBLE-ASSET', 'DEBT-TO-EQUITY', 'EQUITY-TO-ASSET', 'DEBT-TO-ASSET', 'GROSS-PROFIT-TO-ASSET %', 'COGS-TO-REVENUE', 'INVENTORY-TO-REVENUE', 'PRE-TAX INCOME', '  SHORT-TERM DEBT', '  SHORT-TERM CAPITAL LEASE OBLIGATION', 'SHORT-TERM DEBT & CAPITAL LEASE OBLIGATION', '  LONG-TERM DEBT', '  LONG-TERM CAPITAL LEASE OBLIGATION', 'LONG-TERM DEBT & CAPITAL LEASE OBLIGATION', 'OTHER LONG-TERM LIABILITIES', 'ADDITIONAL PAID-IN CAPITAL', 'UNNAMED: 148', 'PRICE-TO-OWNER-EARNINGS', 'PRICE-TO-TANGIBLE-BOOK', 'PRICE-TO-FREE-CASH-FLOW', 'PRICE-TO-OPERATING-CASH-FLOW', 'EV-TO-REVENUE', 'EV-TO-EBITDA', 'EV-TO-EBIT', 'NET-NET WORKING CAPITAL', 'ALTMAN Z-SCORE', 'PIOTROSKI F-SCORE', 'BENEISH M-SCORE', '5-YEAR EBITDA GROWTH RATE']
# 38

# %% [markdown]
# ### remove those with _x, and keep y

# %%
for i in range(len(alldf)):
    for title in alldf[i].columns:
        if title.endswith('_X'):
            alldf[i]=alldf[i].drop(title, axis=1)

# %%
for i in range(len(alldf)):
    for name in alldf[i].columns:
        if name.endswith('_Y'):
            alldf[i].rename(columns={name:name[:-3]}, inplace=True)

# %%
m_col1 = []
for i in alldf[3].columns:
    if i not in alldf[13].columns:
        m_col1.append(i)
print(m_col1)
print(len(m_col1))
# Out:
# ['MACD_SIGNA', 'MAC', 'MACD_HIS', 'SLOWK', 'SLOWD', 'RETURN-ON-TANGIBLE-EQUITY', 'RETURN-ON-TANGIBLE-ASSET', 'DEBT-TO-EQUITY', 'EQUITY-TO-ASSET', 'DEBT-TO-ASSET', 'GROSS-PROFIT-TO-ASSET %', 'COGS-TO-REVENUE', 'INVENTORY-TO-REVENUE', 'PRE-TAX INCOME', '  SHORT-TERM DEBT', '  SHORT-TERM CAPITAL LEASE OBLIGATION', 'SHORT-TERM DEBT & CAPITAL LEASE OBLIGATION', '  LONG-TERM DEBT', '  LONG-TERM CAPITAL LEASE OBLIGATION', 'LONG-TERM DEBT & CAPITAL LEASE OBLIGATION', 'OTHER LONG-TERM LIABILITIES', 'ADDITIONAL PAID-IN CAPITAL', 'UNNAMED: 148', 'PRICE-TO-OWNER-EARNINGS', 'PRICE-TO-TANGIBLE-BOOK', 'PRICE-TO-FREE-CASH-FLOW', 'PRICE-TO-OPERATING-CASH-FLOW', 'EV-TO-REVENUE', 'EV-TO-EBITDA', 'EV-TO-EBIT', 'NET-NET WORKING CAPITAL', 'ALTMAN Z-SCORE', 'PIOTROSKI F-SCORE', 'BENEISH M-SCORE', '5-YEAR EBITDA GROWTH RATE']
# 35

# %%
shape5 =[]

for i in range(len(alldf)):
    shape5.append(alldf[i].shape)

print(shape)
print(shape5)
# Out:
# [(238, 283), (238, 291), (237, 296), (238, 269), (238, 295), (238, 295), (238, 294), (208, 292), (232, 294), (238, 297), (240, 293), (231, 294), (238, 295), (238, 298), (238, 297), (238, 295), (238, 296), (238, 295), (238, 297), (238, 296)]
# [(238, 277), (238, 285), (237, 290), (238, 263), (238, 289), (238, 289), (238, 288), (208, 286), (232, 288), (238, 289), (240, 287), (231, 288), (238, 289), (238, 291), (238, 289), (238, 289), (238, 290), (238, 288), (238, 289), (238, 289)]

# %%
alldf[-7]
# Out:
#                  SMA     SLOW     SLOW  REAL UPPER BAND  REAL LOWER BAND  \
# date
# 2000-01-31   94.3543      NaN      NaN         108.8799          79.8288
# 2000-02-29   83.7710      NaN      NaN         101.4217          66.1203
# 2000-03-31   76.1043      NaN      NaN          90.2603          61.9484
# 2000-04-28   74.9167      NaN      NaN          85.7359          64.0974
# 2000-05-31   80.7500      NaN      NaN          96.6612          64.8388
# ...              ...      ...      ...              ...              ...
# 2019-06-28  137.2100  60.3232  57.6620         145.9223         128.4977
# 2019-07-31  133.5500  51.3817  38.2343         141.6889         125.4111
# 2019-08-30  132.6200  41.8192  29.5614         142.1603         123.0797
# 2019-09-30  129.3200  27.0011  13.2075         130.8411         127.7989
# 2019-10-09  128.9867  18.8327  13.7292         129.8825         128.0908
#
#             REAL MIDDLE BAND    MACD  MACD_SIGNAL  MACD_HIST       EMA  ...  \
# ...

# %% [markdown]
# # save everything back to the file

# %%
alldf[1].to_excel("AGN_L3.xlsx", index=True)

# %%
df_agn.shape
# Out:
# (238, 291)
