# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader as web

# %%
df_sharpe = pd.read_csv("/Users/Nicole/Desktop/FTDS/Capstone/sharpe_all_2.csv",index_col='Date',parse_dates=True)
df_sharpe
# Out:
#             ABT_sharpe  AGN_sharpe  ALXN_sharpe  AMGN_sharpe  BAX_sharpe  \
# Date
# 1998-01-30         NaN         NaN          NaN          NaN         NaN
# 1998-02-27         NaN         NaN          NaN          NaN         NaN
# 1998-03-31         NaN         NaN          NaN          NaN         NaN
# 1998-04-30         NaN         NaN          NaN          NaN         NaN
# 1998-05-29         NaN         NaN          NaN          NaN         NaN
# ...                ...         ...          ...          ...         ...
# 2019-05-31   -0.080837   -0.036831     0.008802    -0.055930   -0.053256
# 2019-06-28   -0.051603   -0.016025     0.011647    -0.024818   -0.035161
# 2019-07-31   -0.047776   -0.014716     0.011747    -0.022004   -0.036717
# 2019-08-30   -0.038562   -0.012652     0.014798    -0.014839   -0.039290
# 2019-09-30   -0.040367   -0.015426     0.018156    -0.012138   -0.045479
#
#             BIIB_sharpe  BMRN_sharpe  BMY_sharpe  CELG_sharpe  DHR_sharpe  \
# Date
# ...

# %%
df_sharpe.head(40)
# Out:
#             ABT_sharpe  AGN_sharpe  ALXN_sharpe  AMGN_sharpe  BAX_sharpe  \
# Date
# 1998-01-30         NaN         NaN          NaN          NaN         NaN
# 1998-02-27         NaN         NaN          NaN          NaN         NaN
# 1998-03-31         NaN         NaN          NaN          NaN         NaN
# 1998-04-30         NaN         NaN          NaN          NaN         NaN
# 1998-05-29         NaN         NaN          NaN          NaN         NaN
# 1998-06-30   -0.209227   -0.144241    -0.058065    -0.144228   -0.300971
# 1998-07-31   -0.211917   -0.124651    -0.056984    -0.161513   -0.167778
# 1998-08-31   -0.151025   -0.271000    -0.066909    -0.072277   -0.112445
# 1998-09-30   -0.112403   -0.135768    -0.025706    -0.051846   -0.085577
# 1998-10-30   -0.095400   -0.109378    -0.017603    -0.041090   -0.074831
# 1998-11-30   -0.110559   -0.125761    -0.018469    -0.049608   -0.093936
# 1998-12-31   -0.193898   -0.113158    -0.027115    -0.049262   -0.178875
# ...

# %%
df_sharpe = df_sharpe.dropna(how = "all")
df_sharpe
# Out:
#             ABT_sharpe  AGN_sharpe  ALXN_sharpe  AMGN_sharpe  BAX_sharpe  \
# Date
# 1998-06-30   -0.209227   -0.144241    -0.058065    -0.144228   -0.300971
# 1998-07-31   -0.211917   -0.124651    -0.056984    -0.161513   -0.167778
# 1998-08-31   -0.151025   -0.271000    -0.066909    -0.072277   -0.112445
# 1998-09-30   -0.112403   -0.135768    -0.025706    -0.051846   -0.085577
# 1998-10-30   -0.095400   -0.109378    -0.017603    -0.041090   -0.074831
# ...                ...         ...          ...          ...         ...
# 2019-05-31   -0.080837   -0.036831     0.008802    -0.055930   -0.053256
# 2019-06-28   -0.051603   -0.016025     0.011647    -0.024818   -0.035161
# 2019-07-31   -0.047776   -0.014716     0.011747    -0.022004   -0.036717
# 2019-08-30   -0.038562   -0.012652     0.014798    -0.014839   -0.039290
# 2019-09-30   -0.040367   -0.015426     0.018156    -0.012138   -0.045479
#
#             BIIB_sharpe  BMRN_sharpe  BMY_sharpe  CELG_sharpe  DHR_sharpe  \
# Date
# ...

# %%
df_sharpe = df_sharpe.apply(lambda x: pd.qcut(x, [0, .25, .75, 1.], labels=["sell", "hold", "buy"]), axis=1)
df_sharpe
# Out:
#            ABT_sharpe AGN_sharpe ALXN_sharpe AMGN_sharpe BAX_sharpe  \
# Date
# 1998-06-30       sell       hold         buy        hold       sell
# 1998-07-31       sell       hold         buy        sell       sell
# 1998-08-31       sell       sell        hold        hold       hold
# 1998-09-30       sell       sell        hold        hold       hold
# 1998-10-30       sell       sell         buy        hold       hold
# ...               ...        ...         ...         ...        ...
# 2019-05-31       hold       hold         buy        hold       hold
# 2019-06-28       hold       hold         buy        hold       hold
# 2019-07-31       hold       hold         buy        hold       hold
# 2019-08-30       hold       hold         buy        hold       hold
# 2019-09-30       hold       hold         buy        hold       hold
#
#            BIIB_sharpe BMRN_sharpe BMY_sharpe CELG_sharpe DHR_sharpe  \
# Date
# ...

# %%
df_sharpe.to_csv("final_targets.csv", index=True)
